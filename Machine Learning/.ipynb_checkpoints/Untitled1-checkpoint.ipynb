# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import re as re
% matplotlib inline
import Getmissed
import Processothers
import Addmissingvalue
from sklearn.linear_model import LogisticRegression
import Addpredict
import Predict
from sklearn.linear_model import Ridge
from imblearn.over_sampling import SMOTE
import Predict_Estimation
from sklearn.model_selection import cross_val_score,train_test_split
import Predict_profit
from sklearn.metrics import r2_score
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
import seaborn as sns

train_df = pd.read_csv('DataTraining.csv')
test_df = pd.read_csv('DataPredict.csv')

train=Getmissed.GetTrain(train_df)
train_df=Processothers.Get_processed_and_complete(train_df,train)
# Out:
# /home/chenyf1/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
'''
def Get_processed_profit_need_data(train_df):
    olabel=train_df['profit']
    y_responded=train_df['responded']
    odata=train_df.drop(columns=['id','responded','profit'])
    odata=pd.get_dummies(odata)
    odata=odata.loc[(y_responded != 0)]
    olabel = olabel[(y_responded !=0)]
    return odata,olabel
'''
# Out:
# "\ndef Get_processed_profit_need_data(train_df):\n    olabel=train_df['profit']\n    y_responded=train_df['responded']\n    odata=train_df.drop(columns=['id','responded','profit'])\n    odata=pd.get_dummies(odata)\n    odata=odata.loc[(y_responded != 0)]\n    olabel = olabel[(y_responded !=0)]\n    return odata,olabel\n"

# %%
train_df
# Out:
#       custAge    profession   marital            schooling  default housing  \
# 0        34.0        admin.    single    university.degree       no      no
# 1        31.0      services    single          high.school       no      no
# 2        33.0        admin.    single          high.school       no      no
# 3        52.0        admin.  divorced    university.degree  unknown     yes
# 4        39.0   blue-collar    single             basic.9y  unknown     yes
# 5        40.0  entrepreneur   married    university.degree       no     yes
# 6        50.0    technician    single  professional.course       no      no
# 7        41.0    technician   married  professional.course       no      no
# 8        23.0   blue-collar    single             basic.4y       no     yes
# 9        29.0    technician   married  professional.course       no     yes
# 10       57.0       retired   married             basic.4y  unknown      no
# 11       33.0   blue-collar   married              unknown       no      no
# 12       40.0    technician   married    university.degree       no     yes
# 13       59.0     housemaid   married             basic.4y  unknown      no
# 14       38.0    technician   married    university.degree       no      no
# 15       44.0   blue-collar   married             basic.9y       no     yes
# 16       33.0    technician    single  professional.course  unknown     yes
# 17       51.0   blue-collar   married             basic.4y       no     yes
# 18       40.0      services   married          high.school       no     yes
# 19       37.0        admin.    single    university.degree       no      no
# 20       33.0        admin.   married          high.school       no     yes
# 21       39.0   blue-collar   married             basic.9y       no     yes
# 22       55.0      services   married          high.school       no     yes
# 23       27.0      services    single  professional.course       no     yes
# 24       24.0       student    single          high.school       no     yes
# 25       40.0      services  divorced          high.school       no     yes
# 26       49.0       unknown   married              unknown       no      no
# 27       25.0    technician   married  professional.course       no      no
# 28       35.0    technician   married              unknown  unknown     yes
# 29       34.0    technician    single  professional.course       no     yes
# ...       ...           ...       ...                  ...      ...     ...
# 8107     48.0    technician   married  professional.course       no     yes
# 8108     34.0   blue-collar   married             basic.6y       no     yes
# 8109     41.0        admin.   married    university.degree       no     yes
# 8110     33.0        admin.    single    university.degree       no      no
# 8111     45.0        admin.   married    university.degree       no      no
# 8112     43.0        admin.  divorced    university.degree       no     yes
# 8113     41.0        admin.    single          high.school       no      no
# 8114     40.0      services   married          high.school  unknown      no
# 8115     32.0   blue-collar    single          high.school       no      no
# 8116     63.0       retired   married              unknown       no     yes
# 8117     31.0   blue-collar   married             basic.9y       no     yes
# 8118     40.0    technician   married    university.degree       no      no
# 8119     61.0    management   married    university.degree       no     yes
# 8120     28.0        admin.   married    university.degree       no     yes
# 8121     64.0        admin.   married    university.degree       no      no
# 8122     27.0        admin.   married    university.degree       no     yes
# 8123     41.0   blue-collar  divorced             basic.9y       no     yes
# 8124     30.0   blue-collar   married             basic.4y       no     yes
# 8125     33.0        admin.    single    university.degree       no     yes
# 8126     33.0        admin.   married    university.degree       no      no
# 8127     31.0    technician   married    university.degree       no     yes
# 8128     65.0       retired   married              unknown       no      no
# 8129     40.0        admin.   married    university.degree       no     yes
# 8130     62.0       retired   married             basic.4y       no      no
# 8131     69.0       retired   married             basic.4y       no      no
# 8132     24.0       student    single    university.degree       no      no
# 8133     29.0        admin.   married    university.degree       no      no
# 8134     48.0    unemployed    single             basic.9y       no     yes
# 8135     54.0        admin.   married              unknown       no     yes
# 8136     31.0        admin.   married    university.degree       no     yes
#
#      loan    contact month day_of_week  ...   emp.var.rate  cons.price.idx  \
# 0     yes   cellular   apr         wed  ...           -1.8          93.075
# 1      no   cellular   jul         thu  ...            1.4          93.918
# 2      no  telephone   jun         thu  ...            1.4          94.465
# 3      no   cellular   jul         tue  ...            1.4          93.918
# 4      no   cellular   jul         tue  ...            1.4          93.918
# 5      no  telephone   jun         thu  ...            1.4          94.465
# 6      no   cellular   jul         tue  ...            1.4          93.918
# 7      no   cellular   oct         thu  ...           -3.4          92.431
# 8      no  telephone   jun         fri  ...            1.4          94.465
# 9      no   cellular   aug         mon  ...            1.4          93.444
# 10     no  telephone   jun         mon  ...            1.4          94.465
# 11     no   cellular   jul         mon  ...            1.4          93.918
# 12     no  telephone   oct         wed  ...           -1.1          94.601
# 13     no  telephone   jun         thu  ...            1.4          94.465
# 14     no   cellular   may         fri  ...           -1.8          92.893
# 15    yes   cellular   may         mon  ...           -1.8          92.893
# 16    yes  telephone   jul         thu  ...            1.4          93.918
# 17    yes  telephone   may         wed  ...            1.1          93.994
# 18     no  telephone   may         wed  ...            1.1          93.994
# 19    yes   cellular   aug         mon  ...            1.4          93.444
# 20    yes  telephone   may         thu  ...            1.1          93.994
# 21     no   cellular   apr         wed  ...           -1.8          93.075
# 22     no   cellular   aug         wed  ...            1.4          93.444
# 23     no   cellular   jun         tue  ...           -2.9          92.963
# 24     no   cellular   may         tue  ...           -1.8          93.876
# 25     no  telephone   apr         fri  ...           -1.8          93.075
# 26     no  telephone   jun         wed  ...            1.4          94.465
# 27     no   cellular   jul         thu  ...            1.4          93.918
# 28     no  telephone   may         tue  ...            1.1          93.994
# 29     no  telephone   may         tue  ...           -1.8          92.893
# ...   ...        ...   ...         ...  ...            ...             ...
# 8107  yes   cellular   apr         thu  ...           -1.8          93.075
# 8108   no  telephone   may         mon  ...            1.1          93.994
# 8109   no   cellular   jul         wed  ...           -1.7          94.215
# 8110   no   cellular   aug         thu  ...           -2.9          92.201
# 8111   no   cellular   sep         mon  ...           -3.4          92.379
# 8112   no   cellular   aug         tue  ...           -2.9          92.201
# 8113   no   cellular   may         mon  ...           -1.8          92.893
# 8114   no  telephone   may         tue  ...            1.1          93.994
# 8115   no  telephone   jun         tue  ...            1.4          94.465
# 8116   no  telephone   apr         wed  ...           -1.8          93.075
# 8117   no   cellular   jun         mon  ...           -2.9          92.963
# 8118   no   cellular   may         mon  ...           -1.8          92.893
# 8119   no   cellular   aug         fri  ...           -2.9          92.201
# 8120   no   cellular   jul         fri  ...            1.4          93.918
# 8121  yes  telephone   apr         thu  ...           -1.8          93.075
# 8122   no   cellular   jul         thu  ...            1.4          93.918
# 8123   no   cellular   nov         wed  ...           -0.1          93.200
# 8124   no   cellular   apr         thu  ...           -1.8          93.075
# 8125   no   cellular   sep         thu  ...           -1.1          94.199
# 8126   no   cellular   nov         tue  ...           -1.1          94.767
# 8127  yes   cellular   oct         tue  ...           -1.1          94.601
# 8128   no   cellular   sep         tue  ...           -3.4          92.379
# 8129   no   cellular   may         tue  ...           -1.8          93.876
# 8130   no   cellular   apr         tue  ...           -1.8          93.075
# 8131   no   cellular   nov         mon  ...           -3.4          92.649
# 8132  yes   cellular   jun         thu  ...           -2.9          92.963
# 8133  yes   cellular   jun         tue  ...           -1.7          94.055
# 8134   no   cellular   apr         tue  ...           -1.8          93.075
# 8135   no   cellular   sep         tue  ...           -3.4          92.379
# 8136   no   cellular   mar         tue  ...           -1.8          92.843
#
#       cons.conf.idx  euribor3m nr.employed   pmonths  pastEmail  responded  \
# 0             -47.1      1.498      5099.1  0.000000          0          0
# 1             -42.7      4.968      5228.1  0.000000          0          0
# 2             -41.8      4.961      5228.1  0.000000          0          0
# 3             -42.7      4.962      5228.1  0.000000          0          0
# 4             -42.7      4.961      5228.1  0.000000          0          0
# 5             -41.8      4.866      5228.1  0.000000          0          0
# 6             -42.7      4.961      5228.1  0.000000          0          0
# 7             -26.9      0.741      5017.5  0.000000          0          0
# 8             -41.8      4.959      5228.1  0.000000          0          0
# 9             -36.1      4.965      5228.1  0.000000          0          0
# 10            -41.8      4.961      5228.1  0.000000          0          0
# 11            -42.7      4.960      5228.1  0.000000          0          0
# 12            -49.5      0.985      4963.6  0.000000          2          0
# 13            -41.8      4.958      5228.1  0.000000          0          0
# 14            -46.2      1.313      5099.1  0.000000          1          0
# 15            -46.2      1.299      5099.1  0.000000          0          0
# 16            -42.7      4.966      5228.1  0.000000          0          0
# 17            -36.4      4.858      5191.0  0.000000          0          0
# 18            -36.4      4.858      5191.0  0.000000          0          0
# 19            -36.1      4.965      5228.1  0.000000          0          0
# 20            -36.4      4.855      5191.0  0.000000          0          0
# 21            -47.1      1.445      5099.1  0.000000          5          0
# 22            -36.1      4.963      5228.1  0.000000          0          0
# 23            -40.8      1.262      5076.2  0.000000          0          0
# 24            -40.0      0.682      5008.7  0.000000          0          0
# 25            -47.1      1.405      5099.1  0.000000          0          0
# 26            -41.8      4.962      5228.1  0.000000          0          0
# 27            -42.7      4.963      5228.1  0.000000          0          0
# 28            -36.4      4.857      5191.0  0.000000          0          0
# 29            -46.2      1.334      5099.1  0.000000          0          0
# ...             ...        ...         ...       ...        ...        ...
# 8107          -47.1      1.365      5099.1  0.000000          1          1
# 8108          -36.4      4.858      5191.0  0.000000          0          1
# 8109          -40.3      0.840      4991.6  0.000000          4          1
# 8110          -31.4      0.829      5076.2  0.500000          4          1
# 8111          -29.8      0.797      5017.5  0.000000          0          1
# 8112          -31.4      0.838      5076.2  0.200000          2          1
# 8113          -46.2      1.244      5099.1  0.000000          0          1
# 8114          -36.4      4.856      5191.0  0.000000          0          1
# 8115          -41.8      4.864      5228.1  0.000000          0          1
# 8116          -47.1      1.445      5099.1  0.000000          0          1
# 8117          -40.8      1.260      5076.2  0.000000          0          1
# 8118          -46.2      1.299      5099.1  0.000000          0          1
# 8119          -31.4      0.869      5076.2  0.133333          2          1
# 8120          -42.7      4.963      5228.1  0.000000          0          1
# 8121          -47.1      1.365      5099.1  0.066667          4          1
# 8122          -42.7      4.957      5228.1  0.000000          0          1
# 8123          -42.0      4.120      5195.8  0.000000          0          1
# 8124          -47.1      1.435      5099.1  0.000000          0          1
# 8125          -37.5      0.879      4963.6  0.200000          2          1
# 8126          -50.8      1.035      4963.6  0.000000          0          1
# 8127          -49.5      0.982      4963.6  0.200000          4          1
# 8128          -29.8      0.788      5017.5  0.000000          0          1
# 8129          -40.0      0.697      5008.7  0.000000          0          1
# 8130          -47.1      1.423      5099.1  0.000000          0          1
# 8131          -30.1      0.715      5017.5  0.000000          0          1
# 8132          -40.8      1.260      5076.2  0.000000          0          1
# 8133          -39.8      0.702      4991.6  0.166667          3          1
# 8134          -47.1      1.365      5099.1  0.066667          1          1
# 8135          -29.8      0.819      5017.5  0.000000          0          1
# 8136          -50.0      1.556      5099.1  0.000000          0          1
#
#       profit    id
# 0        NaN     1
# 1        NaN     2
# 2        NaN     3
# 3        NaN     4
# 4        NaN     5
# 5        NaN     6
# 6        NaN     7
# 7        NaN     8
# 8        NaN     9
# 9        NaN    10
# 10       NaN    11
# 11       NaN    12
# 12       NaN    13
# 13       NaN    14
# 14       NaN    15
# 15       NaN    16
# 16       NaN    17
# 17       NaN    18
# 18       NaN    19
# 19       NaN    20
# 20       NaN    21
# 21       NaN    22
# 22       NaN    23
# 23       NaN    24
# 24       NaN    25
# 25       NaN    26
# 26       NaN    27
# 27       NaN    28
# 28       NaN    29
# 29       NaN    30
# ...      ...   ...
# 8107   465.0  8108
# 8108    15.0  8109
# 8109   188.0  8110
# 8110   180.0  8111
# 8111   227.0  8112
# 8112   218.0  8113
# 8113    90.0  8114
# 8114   -13.0  8115
# 8115    56.0  8116
# 8116   159.0  8117
# 8117    23.0  8118
# 8118   213.0  8119
# 8119   306.0  8120
# 8120   123.0  8121
# 8121   497.0  8122
# 8122   163.0  8123
# 8123   153.0  8124
# 8124   -32.0  8125
# 8125   174.0  8126
# 8126   213.0  8127
# 8127   390.0  8128
# 8128   133.0  8129
# 8129   172.0  8130
# 8130   155.0  8131
# 8131   171.0  8132
# 8132   345.0  8133
# 8133   477.0  8134
# 8134   232.0  8135
# 8135   220.0  8136
# 8136    89.0  8137
#
# [8137 rows x 25 columns]
